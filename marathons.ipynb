# %%
import pandas as pd

# %%
marathons = pd.read_csv('./data/marathonproject.csv')

# %%
marathons.head()
# Out:
#     Question #2 2016 Half 2016 Full 2017 Half 2017 Full 2018 Half 2018 Full  \
# 0  Fastest Time   1:11:15   2:25:42   1:10:58   2:40:25   1:09:25   2:28:16
# 1  Slowest Time   4:54:41   7:00:00   6:18:24   6:38:19   4:48:06   6:34:41
# 2        Median   2:26:18   4:45:19   2:39:34   4:58:14   2:25:32   4:48:21
# 3          Mean   2:31:57   4:47:48   2:43:59   4:54:26   2:31:46   4:48:23
# 4   Question #3       NaN       NaN       NaN       NaN       NaN       NaN
#
#   2019 Half 2019 Full Combined Half  ... Column16364  Column16365  \
# 0   1:10:03   2:34:59       4:41:41  ...         NaN          NaN
# 1   5:03:35   6:43:55      21:04:46  ...         NaN          NaN
# 2   2:26:07   4:41:57       9:57:31  ...         NaN          NaN
# 3   2:32:07   4:42:09      10:19:48  ...         NaN          NaN
# 4       NaN       NaN           NaN  ...         NaN          NaN
#
#    Column16366  Column16367  Column16368  Column16369  Column16370  \
# ...

# %%
marathons.info
# Out:
# <bound method DataFrame.info of                    Question #2             2016 Half          2016 Full  \
# 0                 Fastest Time               1:11:15            2:25:42
# 1                 Slowest Time               4:54:41            7:00:00
# 2                       Median               2:26:18            4:45:19
# 3                         Mean               2:31:57            4:47:48
# 4                  Question #3                   NaN                NaN
# 5   # who beat Oprah, 4:29:20                  17892               1099
# 6             % who beat Oprah                  100%                37%
# 7                  Question #4                   NaN                NaN
# 8                   Lowest %25               0.08910            0.17570
# 9                   Median %50               0.10160            0.19814
# 10                     Top %75               0.11818            0.22362
# 11                 Question #5  2017 had bad weather                NaN
# ...

# %%
marathons.columns
# Out:
# Index(['Question #2', '2016 Half', '2016 Full', '2017 Half', '2017 Full',
#        '2018 Half', '2018 Full', '2019 Half', '2019 Full', 'Combined Half',
#        ...
#        'Column16364', 'Column16365', 'Column16366', 'Column16367',
#        'Column16368', 'Column16369', 'Column16370', 'Column16371',
#        'Column16372', 'Column16373'],
#       dtype='object', length=16384)

# %%
marathons['2016 Half'].value_counts()
# Out:
# 2016 Half
# 1:11:15                 1
# 4:54:41                 1
# 2:26:18                 1
# 2:31:57                 1
# 17892                   1
# 100%                    1
# 0.08910                 1
# 0.10160                 1
# 0.11818                 1
# 2017 had bad weather    1
# Name: count, dtype: int64

# %%
type(2016 Half)
# Out:
#   Cell In[12], line 1
#     type(2016 Half)
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
marathons.plot(kind='bar',
              x ='2016 Full',
              y ='2016 Half');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 marathons.plot(kind='bar',
#       2               x ='2016 Full',
#       3               y ='2016 Half')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
